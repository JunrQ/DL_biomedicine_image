# %%
import json
import pandas as pd
from functional import seq

metrics_file = "research/fresh_train/metrics.json"

# %%
with open(metrics_file, 'r') as file:
    metrics_dict = json.load(file)

# %%
metrics_dict
# Out:
# [{'annotation_number': 10,
#   'data_size': {'test': [762, 3237], 'train': [848, 3588], 'val': [0, 0]},
#   'metrics': {'coverage': 3.053977272727273,
#    'macro_auc': 0.7771562057537551,
#    'macro_f1': 0.4696683552506673,
#    'mean_average_precision': 0.49785450826980304,
#    'micro_auc': 0.8208513413834098,
#    'micro_f1': 0.545276037643287,
#    'one_error': 0.39204545454545453,
#    'ranking_loss': 0.1722880027958153,
#    'ranking_mean_average_precision': 0.701152685979695},
#   'stages': [2]},
#  {'annotation_number': 20,
#   'data_size': {'test': [789, 3338], 'train': [883, 3700], 'val': [0, 0]},
#   'metrics': {'coverage': 5.7265625,
#    'macro_auc': 0.7806821601453587,
#    'macro_f1': 0.26091405567462356,
#    'mean_average_precision': 0.42519698424731894,
#    'micro_auc': 0.8366781625342963,
#    'micro_f1': 0.4722676207604415,
#    'one_error': 0.3776041666666667,
#    'ranking_loss': 0.14897725515669621,
# ...

# %%
seq(metrics_dict).map(lambda b: b['metrics']['ranking_mean_average_precision']).list()

# %%
macro_f1
# Out:
# [0.7502285517268777,
#  0.6899932353803643,
#  0.675332059201053,
#  0.7723935768044359,
#  0.6874328128481318,
#  0.7287510119933389,
#  0.6524546819467272,
#  0.7703427229599106,
#  0.6881024503122491,
#  0.6365933438293864,
#  0.5859374875730261,
#  0.5782629589117729,
#  0.8197014787782398,
#  0.7196314747733752,
#  0.6335720755108971,
#  0.6013652652107683,
#  0.5677787426303706,
#  0.547581261663413]
